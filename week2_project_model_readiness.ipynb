# %% [markdown]
# # Project 2 — Model-Readiness Analysis
#
# ## UCI Bank Marketing
#
# In this project, you will independently examine an instructional version of the UCI Bank Marketing dataset for readiness for a classification workflow.
#
# **Dataset:** `data/bank_marketing_project2.csv`
#
# Read `DATA_SOURCE.md` before beginning.
#
# Use the Week 2 demo and lab as references.

# %% [markdown]
# ## 1. Modeling Task
#
# Explain in your own words:
#
# - what the classification workflow is intended to predict,
# - which field should serve as the target and how you determined that,
# - what the target values represent,
# - what one row appears to represent.
#
# **Your response:**

# %% [markdown]
# ## 2. Initial Dataset Review
#
# Load and inspect the dataset.
#
# Your inspection should help you understand the dataset's size, columns, stored data types, missingness, and general characteristics.
#
# Do not just display output. Add brief interpretation where something appears relevant to model readiness.

# %%
# Import the libraries you need and load the dataset

# %%
# Perform your initial inspection

# %% [markdown]
# ### Initial Review Notes
#
# What stands out from your first inspection?
#
# **Your response:**

# %% [markdown]
# ## 3. Candidate Features and Modeling Roles
#
# Identify:
#
# - plausible candidate features,
# - fields that may require special treatment,
# - fields whose role or meaning needs clarification.
#
# Remember that a pandas dtype does not automatically determine a feature's modeling role.
#
# **Your response:**

# %% [markdown]
# ## 4. Readiness Investigation
#
# Investigate the dataset for characteristics that could affect the supplied classification workflow.
#
# You decide what deserves closer inspection and which tools are appropriate.
#
# Possible areas include:
#
# - missing values,
# - inconsistent categorical values,
# - suspicious or incompatible representations,
# - unusual numerical values,
# - feature roles,
# - target distribution,
# - other modeling-relevant characteristics.

# %%
# Investigation 1

# %% [markdown]
# **Interpretation:**

# %%
# Investigation 2

# %% [markdown]
# **Interpretation:**

# %%
# Investigation 3

# %% [markdown]
# **Interpretation:**

# %%
# Add additional investigation cells as needed

# %% [markdown]
# ## 5. Focused Evidence
#
# Include at least **two targeted summaries or inspections** and **two purposeful visualizations** in your project.
#
# For each visualization, explain the readiness question it helps answer.

# %%
# Visualization 1

# %% [markdown]
# **This visualization helps answer:**

# %%
# Visualization 2

# %% [markdown]
# **This visualization helps answer:**

# %% [markdown]
# ## 6. Provenance and Documentation
#
# Using `DATA_SOURCE.md`, document:
#
# - where the original data came from,
# - the purpose of the original dataset,
# - one source-documented fact that affects how you interpret a field,
# - one limitation, uncertainty, or assumption that should be recorded.
#
# **Your response:**

# %% [markdown]
# ## 7. Model-Readiness Report
#
# Document at least **five meaningful findings** supported by evidence from your notebook.
#
# | Finding | Evidence | Impact on Workflow | Next Step |
# |---|---|---|---|
# | | | | |
# | | | | |
# | | | | |
# | | | | |
# | | | | |

# %% [markdown]
# ## 8. Final Readiness Statement
#
# Write a concise professional conclusion that answers:
#
# 1. Is the dataset ready to use as-is for the supplied classification workflow?
# 2. What are the highest-priority preparation needs?
# 3. What requires further investigation before a change should be made?
#
# **Your response:**

# %% [markdown]
# ---
#
# ## Before You Submit
#
# - Run the notebook from top to bottom.
# - Make sure all outputs needed as evidence are visible.
# - Make sure your written claims are supported by the outputs.
# - Do not implement the full cleaning/preprocessing solution.
# - Commit and push your work.
# - Verify the notebook in the online repository.
# - Submit the repository link in Blackboard.
